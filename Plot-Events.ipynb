# %% [markdown]
# # Comparison of Forward Charm And Neutrino Production

# %% [markdown]
# ## Load Libraries
# At first, I load all the libraries we will need later on.

# %%
from Code import *

# %% [markdown]
# ## Validation

# %%
decays = Decays()
decays.do_decay(model="13TeV_KT_ANNA-linear-BLC2", setups=['FASERv', 'FLARE'])

# %%
models = [
    ["13TeV_KT_ANNA-linear-BLC"      , r"OLD"      , "dodgerblue"  , "solid"    , 1 ],
    ["13TeV_KT_ANNA-linear-BLC2"     , r"NEW"      , "red"         , "dashed"   , 1 ],
]

# %%
plot = Plotting()
plot.plot_histos(histograms='summary', models=models, ncols=2)
# Out:
# OLD 37233653.28832219
# NEW 36835630.02359041
# OLD 242468.8405095182
# NEW 240076.7537928268

# %% [markdown]
# ### Comaprison

# %%
decays = Decays()
#decays.do_decay(model="13TeV_KT_ANNA-linear-BLC2", setups=['FASERv', 'FLARE'])
#decays.do_decay(model="13TeV_KT_ANNA-linear-BLC2", setups=['FASERv', 'FLARE'])

# %%
models = [
    ["13TeV_KT_ANNA-linear-BLC"      , r"KT_ANNA-linear-BLC"      , "firebrick"   , "dashed"  , 1 ],
    ["13TeV_KT_ANNA-saturation-BLC"  , r"KT_ANNA-saturation-BLC"  , "red"         , "solid"   , 1 ],
    ["13TeV_NLO_YUSEON"              , r"NLO_YUSEON"              , "magenta"     , "dashdot" , 1 ],
    ["13TeV_MC_SIBYLL"               , r"MC_SIBYLL"               , "lime"        , "solid"   , 1 ],
    ["13TeV_MC_DPMJET"               , r"MC_DPMJET"               , "green"       , "dashed"  , 1 ],
    ["13TeV_KT_RAFAL-hyb-KSlin"      , r"KT_RAFAL-hyb-KSlin"      , "dodgerblue"  , "solid"   , 1 ],
    ["13TeV_KT_RAFAL-hyb+IC-KSlin"   , r"KT_RAFAL-hyb+IC-KSlin"   , "deepskyblue" , "dashed"  , 1 ],
    ["13TeV_KT_RAFAL-hyb+REC-KSlin"  , r"KT_RAFAL-hyb+REC-KSlin"  , "blue"        , "dashdot" , 1 ],
]

# %%
plot = Plotting()
plot.plot_histos(histograms='use', models=models, ncols=2)
plot.plot_histos(histograms='details', models=models, ncols=3)
# Out:
# KT_ANNA-linear-BLC 37233653.28832219
# KT_ANNA-saturation-BLC 16354163.079640174
# NLO_YUSEON 3798361.480916655
# MC_SIBYLL 4492951.3277874375
# MC_DPMJET 18194915.55384236
# KT_RAFAL-hyb-KSlin 3009070.19700176
# KT_RAFAL-hyb+IC-KSlin 11095447.479614802
# KT_RAFAL-hyb+REC-KSlin 7066880.720221344
# KT_ANNA-linear-BLC 37233653.28832219
# KT_ANNA-saturation-BLC 16354163.079640174
# NLO_YUSEON 3798361.480916655
# MC_SIBYLL 4492951.3277874375
# MC_DPMJET 18194915.55384236
# KT_RAFAL-hyb-KSlin 3009070.19700176
# KT_RAFAL-hyb+IC-KSlin 11095447.479614802
# KT_RAFAL-hyb+REC-KSlin 7066880.720221344
# KT_ANNA-linear-BLC 35842706.815736145
# KT_ANNA-saturation-BLC 15910912.933824405
# NLO_YUSEON 3713300.673724152
# MC_SIBYLL 4333827.057564084
# MC_DPMJET 17707628.662880737
# KT_RAFAL-hyb-KSlin 2894287.6320581464
# KT_RAFAL-hyb+IC-KSlin 10783642.374997133
# KT_RAFAL-hyb+REC-KSlin 6873526.177097179
# KT_ANNA-linear-BLC 2935450.103950532
# KT_ANNA-saturation-BLC 1311924.9998329098
# ...

# %% [markdown]
# ## Generate Event Files

# %%
#decays = Decays()
#decays.do_decay_event(model="13TeV_KT_ANNA-linear-BLC", nsample=50)
#decays.do_decay_event(model="13TeV_KT_ANNA-saturation-BLC", nsample=50)
#decays.do_decay_event(model="13TeV_NLO_YUSEON", nsample=50)
#decays.do_decay_event(model="13TeV_KT_RAFAL-hyb-KSlin", nsample=50)
#decays.do_decay_event(model="13TeV_KT_RAFAL-hyb+IC-KSlin", nsample=50)
#decays.do_decay_event(model="13TeV_KT_RAFAL-hyb+REC-KSlin", nsample=50)
#decays.do_decay_event(model="13TeV_NLO_LUCA", nsample=50)

# %%
decays = Decays()
decays.do_decay_event(
    model="13.6TeV_NLO_Luca_charm_monash_Central", 
    nsample=125, 
    condition="abs(posx)<0.5 and abs(posy)<0.5"
)
# Out:
# /Users/felixkling/Documents/GitHub/ForwardCharm/Code.py:327: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(values)
